# %%
from sqlalchemy import create_engine
import pandas as pd
from snowflake.sqlalchemy import URL

engine = create_engine(
    'snowflake://{user}:{password}@{account}/d'.format(
        user='ESTPEGION',
        password='SnowFlake1234!',
        account='mg61873.ca-central-1.aws',
        database = 'KPMG',
        schema = 'public',
        warehouse = 'COMPUTE_WH',
        role='accountadmin',
        numpy = True
    )
)

connection = engine.connect()
results = connection.execute('select current_version()').fetchone()
print(results[0])

import pandas as pd
pd.read_sql_query('''USE SCHEMA SNOWFLAKE_SAMPLE_DATA.TPCDS_SF10TCL;''',engine)
# finally:
#     connection.close()
#     engine.dispose()
# Out:
# 7.8.1
#                              status
# 0  Statement executed successfully.

# %%
pd.read_sql_query('''USE SCHEMA SNOWFLAKE_SAMPLE_DATA.TPCDS_SF10TCL;''',engine)
# Out:
#                              status
# 0  Statement executed successfully.

# %%
# url = f'snowflake://ESTPEGION:SnowFlake1234!@mg61873.ca-central-1.aws/KPMG/public?warehouse=testwh&role=myrole'

# %%
# test if connection works
pd.read_sql_query('select * from WEB_SALES limit 100',engine)
# Out:
#     ws_sold_date_sk  ws_sold_time_sk  ws_ship_date_sk  ws_item_sk  \
# 0           2451864             3080          2451926      204037
# 1           2451864            16316          2451884      204037
# 2           2451864            64808          2451976      204037
# 3           2451864            62886          2451932      204037
# 4           2451864            67631          2451907      204037
# ..              ...              ...              ...         ...
# 95          2451864            39861          2451977      204043
# 96          2451864            48547          2451937      204043
# 97          2451864            19581          2451918      204043
# 98          2451864            54038          2451868      204043
# 99          2451864            20589          2451946      204043
#
#     ws_bill_customer_sk  ws_bill_cdemo_sk  ws_bill_hdemo_sk  ws_bill_addr_sk  \
# 0              28943167             84819              5671         19067770
# ...

# %%
q60_c = pd.read_sql_query('select DISTINCT I_category from item limit 100',engine)

# %% [markdown]
# # Variable_Store_Json

# %%
#YEAR.01 corresponding to d_year of date_dim

pd.read_sql_query('''SELECT DISTINCT d_year FROM date_dim;''', engine)
# Out:
#      d_year
# 0      1900
# 1      1901
# 2      1902
# 3      1903
# 4      1904
# ..      ...
# 196    2057
# 197    2064
# 198    2071
# 199    2082
# 200    2049
#
# [201 rows x 1 columns]

# %%
#STATE.01 corresponding to s_state in store

q1_state = pd.read_sql_query('''SELECT DISTINCT s_state FROM store;''', engine)

# %%
list(q1_state.values.T[0]).
# Out:
# ['TN',
#  'NM',
#  'KY',
#  'IA',
#  'NC',
#  'OH',
#  'GA',
#  'IN',
#  'AL',
#  'SC',
#  'MD',
#  'LA',
#  'SD',
#  'MI',
#  'FL',
#  'WV',
#  'VT',
#  'TX',
#  'MT',
#  'CA',
#  'NJ',
#  'CO',
#  'OK',
#  'IL',
#  None,
#  'NE',
#  'OR',
#  'NY',
#  'MO',
#  'WI',
#  'VA',
#  'PA',
#  'WA',
#  'KS',
#  'MN']

# %%
list(q60_c.values.T[0])
# Out:
# ['Sports',
#  'Children',
#  'Women',
#  None,
#  'Home',
#  'Electronics',
#  'Jewelry',
#  'Men',
#  'Shoes',
#  'Music',
#  'Books']

# %%
#Add variable in json here!

import json
var_store = {}
var_store['q1_state'] = ['TN',
 'NM',
 'KY',
 'IA',
 'NC',
 'OH',
 'GA',
 'IN',
 'AL',
 'SC',
 'MD',
 'LA',
 'SD',
 'MI',
 'FL',
 'WV',
 'VT',
 'TX',
 'MT',
 'CA',
 'NJ',
 'CO',
 'OK',
 'IL',
 'None',
 'NE',
 'OR',
 'NY',
 'MO',
 'WI',
 'VA',
 'PA',
 'WA',
 'KS',
 'MN']



var_store['q1_agg'] = ['SR_RETURN_AMT','SR_RETURN_AMT_INC_TAX','SR_RETURN_QUANTITY','SR_RETURN_TAX','SR_RETURN_SHIP_COST']
var_store['q3_aggc']= ["ss_sold_date_sk","ss_sold_time_sk","ss_item_sk","ss_customer_sk","ss_cdemo_sk","ss_hdemo_sk","ss_addr_sk","ss_store_sk","ss_promo_sk","ss_ticket_number","ss_quantity","ss_wholesale_cost","ss_list_price","ss_sales_price","ss_ext_discount_amt","ss_ext_sales_price","ss_ext_wholesale_cost","ss_ext_list_price","ss_ext_tax","ss_coupon_amt","ss_net_paid","ss_net_paid_inc_tax","ss_net_profit"] 
var_store['q60_c'] = list(q60_c.values.T[0])
var_store

var_store_json = json.dumps(var_store,sort_keys=False,separators=(',', ': '))
# Writing to var_store.json
with open("var_store.json", "w") as outfile:
    outfile.write(var_store_json)

# %%
type(json.load(open('var_store.json'))['q1_state'])
type(json.load(open('var_store.json'))['q3_aggc'])
type(json.load(open('var_store.json'))['q60_c'])
# Out:
# list

# %% [markdown]
# ## Adding a new feature into json file

# %%
import json

# %%
q40 = pd.read_sql_query('select DISTINCT I_category from item limit 100',engine)

# %%
 pd.read_sql_query('''SELECT w_state,
       i_item_id,
       sum(CASE
               WHEN (cast(d_date AS date) < CAST ('2000-03-11' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
               ELSE 0
           END) AS sales_before,
       sum(CASE
               WHEN (cast(d_date AS date) >= CAST ('2000-03-11' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
               ELSE 0
           END) AS sales_after
FROM catalog_sales
LEFT OUTER JOIN catalog_returns ON (cs_order_number = cr_order_number
                                    AND cs_item_sk = cr_item_sk) ,warehouse,
                                                                  item,
                                                                  date_dim
WHERE i_current_price BETWEEN 0.99 AND 1.49
  AND i_item_sk = cs_item_sk
  AND cs_warehouse_sk = w_warehouse_sk
  AND cs_sold_date_sk = d_date_sk
  AND d_date BETWEEN CAST ('2000-02-10' AS date) AND CAST ('2000-04-10' AS date)
GROUP BY w_state,
         i_item_id
ORDER BY w_state,
         i_item_id
LIMIT 1000;''',engine)
# Out:
#     w_state         i_item_id  sales_before  sales_after
# 0        CO  AAAAAAAAAAAACAAA      -4932.99     -6822.47
# 1        CO  AAAAAAAAAAADCAAA       2163.37      3797.53
# 2        CO  AAAAAAAAAAADFAAA     -10106.44     -1931.34
# 3        CO  AAAAAAAAAAAMEAAA       5457.73      1675.55
# 4        CO  AAAAAAAAAABADAAA      -1019.05     -3539.70
# ..      ...               ...           ...          ...
# 995      CO  AAAAAAAAAPOFDAAA      -4157.84      -587.78
# 996      CO  AAAAAAAAAPOKEAAA        476.11       728.79
# 997      CO  AAAAAAAAAPOLBAAA       1467.82     -3560.68
# 998      CO  AAAAAAAAAPOMAAAA      -2198.05      3905.91
# 999      CO  AAAAAAAAAPPCCAAA       1425.75      1956.43
#
# [1000 rows x 4 columns]

# %%
pd.read_sql_query('select distinct d_date  from catalog_sales  limit 100 ',engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\envs\snowpark\lib\site-packages\sqlalchemy\engine\base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\snowpark\lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# ...

# %%
pd.read_sql_query('select max(d_date), min(d_date)  from date_dim  limit 100 ',engine)
# Out:
#   MAX(D_DATE) MIN(D_DATE)
# 0  2100-01-01  1900-01-02

# %%
pd.read_sql_query('''select max(d_date), min(d_date)  from date_dim  where  d_date != '2100-01-01' ''',engine)
# Out:
#   MAX(D_DATE) MIN(D_DATE)
# 0  2099-12-31  1900-01-02

# %%
from datetime import date, timedelta
SALES_DATE = date(2000, 3, 11)

# %%
str(SALES_DATE)
# Out:
# '2000-03-11'

# %%
q40 = f'''SELECT w_state,
       i_item_id,
       sum(CASE
               WHEN (cast(d_date AS date) < CAST (\'{SALES_DATE}\' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
               ELSE 0
           END) AS sales_before,
       sum(CASE
               WHEN (cast(d_date AS date) >= CAST (\'{SALES_DATE}\' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
               ELSE 0
           END) AS sales_after
FROM catalog_sales
LEFT OUTER JOIN catalog_returns ON (cs_order_number = cr_order_number
                                    AND cs_item_sk = cr_item_sk) ,warehouse,
                                                                  item,
                                                                  date_dim
WHERE i_current_price BETWEEN 0.99 AND 1.49
  AND i_item_sk = cs_item_sk
  AND cs_warehouse_sk = w_warehouse_sk
  AND cs_sold_date_sk = d_date_sk
  AND d_date BETWEEN CAST (\'{SALES_DATE-timedelta(days=60)}\' AS date) AND CAST (\'{SALES_DATE+timedelta(days=60)}\' AS date)
GROUP BY w_state,
         i_item_id
ORDER BY w_state,
         i_item_id
LIMIT 100;

        '''

# %%
print(q40)
# Out:
# SELECT w_state,
#        i_item_id,
#        sum(CASE
#                WHEN (cast(d_date AS date) < CAST ('2000-03-11' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
#                ELSE 0
#            END) AS sales_before,
#        sum(CASE
#                WHEN (cast(d_date AS date) >= CAST ('2000-03-11' AS date)) THEN cs_sales_price - coalesce(cr_refunded_cash,0)
#                ELSE 0
#            END) AS sales_after
# FROM catalog_sales
# LEFT OUTER JOIN catalog_returns ON (cs_order_number = cr_order_number
#                                     AND cs_item_sk = cr_item_sk) ,warehouse,
#                                                                   item,
#                                                                   date_dim
# WHERE i_current_price BETWEEN 0.99 AND 1.49
#   AND i_item_sk = cs_item_sk
#   AND cs_warehouse_sk = w_warehouse_sk
#   AND cs_sold_date_sk = d_date_sk
# ...

# %%
pd.read_sql_query(q40,engine)
# Out:
#    w_state         i_item_id  sales_before  sales_after
# 0       CO  AAAAAAAAAAAACAAA      -7551.53     -3744.13
# 1       CO  AAAAAAAAAAADCAAA       3618.18      2069.04
# 2       CO  AAAAAAAAAAADFAAA     -13908.99      1701.06
# 3       CO  AAAAAAAAAAAMEAAA        256.04       535.31
# 4       CO  AAAAAAAAAABADAAA         11.24    -10430.48
# ..     ...               ...           ...          ...
# 95      CO  AAAAAAAAABCFAAAA      -3880.07      7196.06
# 96      CO  AAAAAAAAABCHEAAA       4999.17    -10645.58
# 97      CO  AAAAAAAAABCICAAA     -10687.52    -13317.41
# 98      CO  AAAAAAAAABCKAAAA        543.90      6280.66
# 99      CO  AAAAAAAAABCLDAAA       4242.74    -12036.42
#
# [100 rows x 4 columns]

# %%
with open('src/05.txt', 'r') as file:
    data = file.read()

# %%
print(data.replace('2000-08-23', str(SALES_DATE)).replace('2000-09-06',str(SALES_DATE+timedelta(days=14))))
# Out:
# WITH ssr AS
#   (SELECT s_store_id,
#           sum(sales_price) AS sales,
#           sum(profit) AS profit,
#           sum(return_amt) AS returns_,
#           sum(net_loss) AS profit_loss
#    FROM
#      (SELECT ss_store_sk AS store_sk,
#              ss_sold_date_sk AS date_sk,
#              ss_ext_sales_price AS sales_price,
#              ss_net_profit AS profit,
#              cast(0 AS decimal(7,2)) AS return_amt,
#              cast(0 AS decimal(7,2)) AS net_loss
#       FROM store_sales
#       UNION ALL SELECT sr_store_sk AS store_sk,
#                        sr_returned_date_sk AS date_sk,
#                        cast(0 AS decimal(7,2)) AS sales_price,
#                        cast(0 AS decimal(7,2)) AS profit,
#                        sr_return_amt AS return_amt,
#                        sr_net_loss AS net_loss
#       FROM store_returns ) salesreturns,
#         date_dim,
#         store
#    WHERE date_sk = d_date_sk
# ...

# %%
pd.read_sql_query(data,engine)
# Out:
#             channel                            id         sales     returns_  \
# 0   catalog channel  catalog_pageAAAAAAAAAAACAAAA  0.000000e+00      7286.22
# 1   catalog channel  catalog_pageAAAAAAAAAAAEAAAA  1.775306e+07         0.00
# 2   catalog channel  catalog_pageAAAAAAAAAABCAAAA  0.000000e+00     15558.77
# 3   catalog channel  catalog_pageAAAAAAAAAABEAAAA  1.773628e+07         0.00
# 4   catalog channel  catalog_pageAAAAAAAAAAFDAAAA  0.000000e+00  12941515.01
# ..              ...                           ...           ...          ...
# 95  catalog channel  catalog_pageAAAAAAAAAENDAAAA  0.000000e+00    411769.12
# 96  catalog channel  catalog_pageAAAAAAAAAEODAAAA  2.488216e+08    113546.65
# 97  catalog channel  catalog_pageAAAAAAAAAEPBAAAA  0.000000e+00    493284.22
# 98  catalog channel  catalog_pageAAAAAAAAAEPDAAAA  2.499683e+08    169239.75
# 99  catalog channel  catalog_pageAAAAAAAAAFACAAAA  0.000000e+00      7743.75
#
#          profit
# 0      -6578.74
# ...
