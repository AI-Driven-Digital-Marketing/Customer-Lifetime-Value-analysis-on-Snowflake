# %%
import snowflake.snowpark
from snowflake.snowpark import functions as F
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import IntegerType, StringType, StructType, FloatType, StructField, DateType, Variant
from snowflake.snowpark.functions import udf, sum, col,array_construct,month,year,call_udf,lit,count
from snowflake.snowpark.version import VERSION
# Misc
import json
import pandas as pd
import numpy as np
import logging 
logger = logging.getLogger("snowflake.snowpark.session")
logger.setLevel(logging.ERROR)

# %%
# Create Snowflake Session object
connection_parameters = json.load(open('connection.json'))
session = Session.builder.configs(connection_parameters).create()
session.sql_simplifier_enabled = True

snowflake_environment = session.sql('select current_user(), current_role(), current_database(), current_schema(), current_version(), current_warehouse()').collect()
snowpark_version = VERSION

# # Current Environment Details
# print('User                        : {}'.format(snowflake_environment[0][0]))
# print('Role                        : {}'.format(snowflake_environment[0][1]))
# print('Database                    : {}'.format(snowflake_environment[0][2]))
# print('Schema                      : {}'.format(snowflake_environment[0][3]))
# print('Warehouse                   : {}'.format(snowflake_environment[0][5]))
# print('Snowflake version           : {}'.format(snowflake_environment[0][4]))
# print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Create Snowflake Session object
#       2 connection_parameters = json.load(open('connection.json'))
# ----> 3 session = Session.builder.configs(connection_parameters).create()
#       4 session.sql_simplifier_enabled = True
#       6 snowflake_environment = session.sql('select current_user(), current_role(), current_database(), current_schema(), current_version(), current_warehouse()').collect()
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/snowpark/session.py:232, in Session.SessionBuilder.create(self)
#     230 if "connection" in self._options:
#     231     return self._create_internal(self._options["connection"])
# --> 232 return self._create_internal(conn=None)
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/snowpark/session.py:238, in Session.SessionBuilder._create_internal(self, conn)
#     234 def _create_internal(
#     235     self, conn: Optional[SnowflakeConnection] = None
#     236 ) -> "Session":
#     237     new_session = Session(
# --> 238         ServerConnection({}, conn) if conn else ServerConnection(self._options)
#     239     )
#     240     if "password" in self._options:
#     241         self._options["password"] = None
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:138, in ServerConnection.__init__(self, options, conn)
#     136 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     137 self._add_application_name()
# --> 138 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     139 if "password" in self._lower_case_parameters:
#     140     self._lower_case_parameters["password"] = None
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/__init__.py:51, in Connect(**kwargs)
#      50 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 51     return SnowflakeConnection(**kwargs)
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/connection.py:292, in SnowflakeConnection.__init__(self, **kwargs)
#     290 self.converter = None
#     291 self.__set_error_attributes()
# --> 292 self.connect(**kwargs)
#     293 self._telemetry = TelemetryClient(self._rest)
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/connection.py:542, in SnowflakeConnection.connect(self, **kwargs)
#     540         connection_diag.generate_report()
#     541 else:
# --> 542     self.__open_connection()
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/connection.py:781, in SnowflakeConnection.__open_connection(self)
#     779 auth = Auth(self.rest)
#     780 auth.read_temporary_credentials(self.host, self.user, self._session_parameters)
# --> 781 self._authenticate(auth_instance)
#     783 self._password = None  # ensure password won't persist
#     785 if self.client_session_keep_alive:
#     786     # This will be called after the heartbeat frequency has actually been set.
#     787     # By this point it should have been decided if the heartbeat has to be enabled
#     788     # and what would the heartbeat frequency be
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/connection.py:1044, in SnowflakeConnection._authenticate(self, auth_instance)
#    1041 def _authenticate(self, auth_instance):
#    1042     # make some changes if needed before real __authenticate
#    1043     try:
# -> 1044         self.__authenticate(self.__preprocess_auth_instance(auth_instance))
#    1045     except ReauthenticationRequest as ex:
#    1046         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1047         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/connection.py:1064, in SnowflakeConnection.__authenticate(self, auth_instance)
#    1062 auth = Auth(self.rest)
#    1063 try:
# -> 1064     auth.authenticate(
#    1065         auth_instance=auth_instance,
#    1066         account=self.account,
#    1067         user=self.user,
#    1068         database=self.database,
#    1069         schema=self.schema,
#    1070         warehouse=self.warehouse,
#    1071         role=self.role,
#    1072         passcode=self._passcode,
#    1073         passcode_in_password=self._passcode_in_password,
#    1074         mfa_callback=self._mfa_callback,
#    1075         password_callback=self._password_callback,
#    1076         session_parameters=self._session_parameters,
#    1077     )
#    1078 except OperationalError:
#    1079     logger.debug(
#    1080         "Operational Error raised at authentication"
#    1081         f"for authenticator: {type(auth_instance).__name__}"
#    1082     )
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/auth.py:399, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     397     if type(auth_instance) is AuthByUsrPwdMfa:
#     398         delete_temporary_credential(self._rest._host, user, MFA_TOKEN)
# --> 399     Error.errorhandler_wrapper(
#     400         self._rest._connection,
#     401         None,
#     402         DatabaseError,
#     403         {
#     404             "msg": (
#     405                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     406             ).format(
#     407                 host=self._rest._host,
#     408                 port=self._rest._port,
#     409                 message=ret["message"],
#     410             ),
#     411             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     412             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     413         },
#     414     )
#     415 else:
#     416     logger.debug(
#     417         "token = %s", "******" if ret["data"]["token"] is not None else "NULL"
#     418     )
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/errors.py:276, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     253 @staticmethod
#     254 def errorhandler_wrapper(
#     255     connection: SnowflakeConnection | None,
#    (...)
#     258     error_value: dict[str, str | bool | int],
#     259 ) -> None:
#     260     """Error handler wrapper that calls the errorhandler method.
#     261
#     262     Args:
#    (...)
#     273         exception to the first handler in that order.
#     274     """
# --> 276     handed_over = Error.hand_to_other_handler(
#     277         connection,
#     278         cursor,
#     279         error_class,
#     280         error_value,
#     281     )
#     282     if not handed_over:
#     283         raise Error.errorhandler_make_exception(
#     284             error_class,
#     285             error_value,
#     286         )
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/errors.py:334, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     332     return True
#     333 elif connection is not None:
# --> 334     connection.errorhandler(connection, cursor, error_class, error_value)
#     335     return True
#     336 return False
#
# File ~/opt/anaconda3/envs/SNPark/lib/python3.8/site-packages/snowflake/connector/errors.py:210, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     192 @staticmethod
#     193 def default_errorhandler(
#     194     connection: SnowflakeConnection,
#    (...)
#     197     error_value: dict[str, str],
#     198 ) -> None:
#     199     """Default error handler that raises an error.
#     200
#     201     Args:
#    (...)
#     208         A Snowflake error.
#     209     """
# --> 210     raise error_class(
#     211         msg=error_value.get("msg"),
#     212         errno=error_value.get("errno"),
#     213         sqlstate=error_value.get("sqlstate"),
#     214         sfqid=error_value.get("sfqid"),
#     215         done_format_msg=error_value.get("done_format_msg"),
#     216         connection=connection,
#     217         cursor=cursor,
#     218     )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: ozb65844.us-east-1.snowflakecomputing.com:443. Your free trial has ended and all of your virtual warehouses have been suspended. Add billing information in the Snowflake web UI to continue using the full set of Snowflake features.

# %%
ca_zip = json.load(open('src/zip_json.json'))

# %%
# %%writefile pages/CLV_prediction.py
import pandas as pd
import streamlit as st
import json
import numpy as np
import sys
import cachetools
import joblib
# from streamlit.report_thread import get_report_ctx
# from streamlit.server.server import Server
import snowflake.snowpark
from snowflake.snowpark import functions as F
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import PandasDataFrame,PandasSeries
from snowflake.snowpark.functions import udf, sum, col,array_construct,month,year,call_udf,lit,count
from snowflake.snowpark.version import VERSION

st.set_page_config(page_title= "Customer Lifetime Value")

st.image(
    "src/1649251328-maximize-your-clv.webp",
    width = 600,
)

#st.title("XGBoost model to predict CLV")

col1, col2 = st.columns(2,gap = "medium")
with col1:
    st.markdown('#### Numeric Features')
    Cus_by = st.number_input('Customer Birth Year:', 
                    min_value=1924,
                    max_value=2020, 
                    help = 'Please type VALID birth Year!!(Range: 1924~2020)'
                            )

    Cs_zip = st.number_input( 'Customer Zip Code:', 
                    min_value= 601, 
                    max_value= 99981,
                    value  = 66668,
                    step = 1
                            )


with col2:
    st.markdown('#### Categorical Features ')
    Cus_gender = st.selectbox('CD_Gender',
                              ['M', 'F'], 
                              help= 'M: Male, F: Female'
     )

    Cus_marital = st.selectbox( 'CD_MARITAL_STATUS',
                 ['S','D','W', 'U', 'M'],
     )
    Cus_credit = st.selectbox('CD_CREDIT_RATING',
                 ['Low Risk','Unknown','Good','High Risk']
       )

    Cus_edu = st.selectbox( 'CD_EDUCATION_STATUS',
                 ['Advanced Degree','Secondary','2 yr Degree','4 yr Degree','Unknown','Primary','College']
                )
    Cus_dep = st.selectbox( 'CD_DEP_COUNT',
                 ['0', '1'],
      )



col3, col4 = st.columns([8,2],gap = "medium")

with col3:
    model_select = st.radio('Select the Model here:',
                           [ 'XGBoost','Linear Regression']
                            #[ 'XGBoost']
                           )
with col4:
    submit =  st.button('Submit')
    reset = st.button('Reset ')
@st.cache_resource
def initialize_SF():
    connection_parameters = json.load(open('connection.json'))
    session = Session.builder.configs(connection_parameters).create()
    session.sql_simplifier_enabled = True
    ca_zip = json.load(open('src/zip_json.json'))    
    # set up feature engineering/inference warehouse
    session.use_warehouse('FE_AND_INFERENCE_WH')
    session.use_database('tpcds_xgboost')
    session.use_schema('demo')
    session.add_packages('snowflake-snowpark-python', 'scikit-learn', 'pandas', 'numpy', 'joblib', 'cachetools', 'xgboost==1.5.0', 'joblib')
    session.add_import("@ml_models_10T/model.joblib")  
    session.add_import("@ml_models_LR_10T/model_LR.joblib")
    return session, ca_zip
session, ca_zip = initialize_SF()

# choose model here
if model_select == 'XGBoost':    
    stage_name = 'ml_models_10T'
    model_name = 'model.joblib'
    
else:
    stage_name = 'ml_models_LR_10T'
    model_name = 'model_LR.joblib'

features = [ 'C_BIRTH_YEAR', 'CA_ZIP', 'CD_GENDER', 'CD_MARITAL_STATUS', 'CD_CREDIT_RATING', 'CD_EDUCATION_STATUS', 'CD_DEP_COUNT']

@cachetools.cached(cache={})
def read_file(filename):
    import os, joblib
    import_dir = sys._xoptions.get("snowflake_import_directory")
    if import_dir:
        with open(os.path.join(import_dir, filename), 'rb') as file:
            m = joblib.load(file)
            return m

@F.pandas_udf(session=session, max_batch_size=10000, is_permanent=True, stage_location=f'@{stage_name}', replace=True, name="clv_xgboost_udf")
def predict(df:  PandasDataFrame[int, str, str, str, str, str, int]) -> PandasSeries[float]:
    m = read_file(model_name)       
    df.columns = features
    return m.predict(df) 

# if click submit
if submit:
    typed_input = [[Cus_by, ca_zip.get(str(Cs_zip), '66668'),Cus_gender,Cus_marital,Cus_credit,Cus_edu, int(Cus_dep)]]
    #st.write(typed_input)
    input_df = session.create_dataframe(typed_input, schema=features)
    typed_output = input_df.select(*input_df,
                    predict(*input_df).alias('PREDICTION'))
    output = pd.DataFrame(typed_output.collect()).T
    output.columns = ['']
    st.write(output)
# if click reset  
if reset:
    st.write('放弃reset？')
# Out:
# Overwriting pages/CLV_prediction.py

# %%
# %%writefile Customer_Lifetime_Value.py
import pandas as pd
import streamlit as st

st.write('## Introduction')
# Out:
# Overwriting Customer_Lifetime_Value.py
